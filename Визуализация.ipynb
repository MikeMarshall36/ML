# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.random.randint(0,100,size=(50), dtype=int)
a = np.array(a)
print(len(a))
# Out:
# 50

# %%
b = np.random.randint(0,100,size=(50), dtype=int)
b = np.array(b)
print(len(b))
# Out:
# 50

# %%
dic = {
    "col1":a,
    "col2":b
}

df = pd.DataFrame(dic)
df.head()
# Out:
#    col1  col2
# 0    15    83
# 1    37     0
# 2    66     4
# 3    10    49
# 4    99    12

# %%
plt.plot(a)
plt.show()

# %%
plt.plot(a, b)
plt.show()

# %%
plt.plot(df["col1"])
plt.show()

# %%
l4 = np.random.randint(0,100,size=(50), dtype=int)

# %%
#a.plot;

# %%
plt.plot(a, color='orange', linestyle='dashed', marker='*')
plt.grid(color='gray')
plt.show()

# %%
sns.set_style('darkgrid')
sns.lineplot(data=df, x=df.index, y='col1');

# %%
plt.scatter(df['col1'], df['col2'])
plt.show()

# %%
sns.scatterplot(data=df, x='col1', y='col2');

# %%
plt.hist(df['col1'], density=True)
plt.show()

# %%
sns.histplot(df['col1']);

# %%
sns.boxplot(x='col1', data=df);

# %%
sns.kdeplot(df['col2']);

# %%
sns.kdeplot(x=df['col1'], y=df['col2'], lable='Двумерная ядерная плотность');
plt.legend(fontsize=9)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1213: UserWarning: The following kwargs were not used by contour: 'lable'
#   **contour_kws,
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
dic = {
    'col1':[-1, 2, 3, 4],
    'col2':[5, 6, 0, 7],
    'col3':[1, 2, -3, -2],
    'col4':[4, 2, 5, 9]
}

df_2 = pd.DataFrame(dic)

sns.heatmap(df_2)

# %%
f = plt.figure()
ax = f.subplots(2, 3)
plt.show()
